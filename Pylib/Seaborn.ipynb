# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# C:\Users\chpra\anaconda3\lib\site-packages\seaborn\utils.py:384: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\Users\chpra\anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x = 'day', y= 'total_bill', data= tips)

# %%
sns.barplot(x = 'day', y= 'total_bill', hue= 'sex', data= tips)

# %%
sns.palplot(sns.color_palette('deep',5))

# %%
sns.palplot(sns.color_palette('spring',6))

# %%
custom = ['red','blue', 'green']

# %%
sns.set_palette(custom)

# %%
sns.palplot(sns.color_palette())

# %%
sns.barplot(x = 'total_bill', y= 'day', data= tips)

# %%
sns.barplot(x = 'total_bill', y= 'day', data= tips, order = ['Fri','Sun','Sat','Thur'])

# %%
tst_palette = ['purple','pink','blue','green']
sns.set_palette(tst_palette)

# %%
sns.barplot(x = 'total_bill', y= 'day', data= tips, palette= tst_palette)

# %%
tst_palette = ['pink','green','blue','purple']
sns.set_palette(tst_palette)

# %%
sns.barplot(x = 'total_bill', y= 'day', data= tips, order = ['Fri','Sun','Sat','Thur'])

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
sns.barplot(x='year', y='passengers', data = flights)  #provides an estimation of central tendency

# %%
sns.barplot(x='year', y='passengers', data = flights, palette= 'winter_r')

# %%
sns.barplot(x='month', y='passengers', data = flights)

# %%
sns.barplot(x='month',y='passengers',data= flights, order = ['February','November'])

# %%
sns.barplot(x='month',y='passengers',data= flights, order = ['July','August'])

# %%
flights.passengers[flights.month=='July'].sum()
# Out:
# 4216

# %%
flights.passengers[flights.month=='August'].sum()
# Out:
# 4213

# %%
sns.palplot(sns.color_palette('spring',5))

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x = 'day', y = 'total_bill', data = tips)

# %%
sns.barplot(x = 'day', y = 'total_bill', estimator=np.median , data = tips)

# %%
sns.barplot(x = 'day', y = 'total_bill', data = tips, ci=60)

# %%
sns.barplot(x = 'day', y = 'total_bill', data = tips, ci=60, capsize= 0.3)

# %%
sns.barplot(x = 'day', y = 'total_bill', data = tips, color= 'green')

# %%
sns.barplot(x = 'day', y = 'total_bill', data = tips,color = 'green', saturation= 0.4)

# %%
sns_plot = sns.barplot(x='total_bill', y ='day',data=tips)

# %%
fig = sns_plot.get_figure()
fig.savefig(fname = 'plot.png')

# %%
sns.get_dataset_names()
# Out:
# C:\Users\chpra\anaconda3\lib\site-packages\seaborn\utils.py:384: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\Users\chpra\anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
penguins = sns.load_dataset('penguins')
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
sns.barplot(x='species', y='bill_length_mm', data=penguins)

# %%
sns.barplot(x='species', y='bill_length_mm', data=penguins, estimator=np.median)

# %%
sns.barplot(x='sex', y='flipper_length_mm', data=penguins)

# %%
sns.barplot(x='sex', y='flipper_length_mm', data=penguins, ci=100)

# %%
sns.barplot(x='sex', y='flipper_length_mm', data=penguins, ci=100, capsize=0.2, saturation=0.4, color='blue')

# %%
tst_plot = sns.barplot(x='island', y='body_mass_g', data=penguins, palette='spring')

# %%
fig = tst_plot.get_figure()
fig.savefig(fname='plot.png')

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
sns.distplot(penguins.flipper_length_mm)

# %%
sns.distplot(penguins.flipper_length_mm, rug=True)

# %%
sns.distplot(penguins.flipper_length_mm, kde=False)

# %%
sns.distplot(penguins.flipper_length_mm, hist=False)

# %%
sns.distplot(penguins.flipper_length_mm, bins=20)

# %%
sns.distplot(penguins.flipper_length_mm, rug_kws={'color':'red','height':'0.30'}, rug=True)

# %%
sns.distplot(penguins.flipper_length_mm, kde=False, hist_kws={'color':'blue','alpha':0.2,'histtype':'stepfilled'})

# %%
sns.distplot(penguins.flipper_length_mm, hist=False, kde_kws={'color':'red','lw':5,'alpha':0.49})

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
sns.boxplot(penguins.bill_length_mm)

# %%
sns.boxplot(x=penguins.island, y=penguins.bill_length_mm)
#or sns.boxplot(x='island',y='bill_length_mm',data=penguins)

# %%
sns.boxplot(x=penguins.island, y=penguins.bill_length_mm, hue= penguins.sex)

# %%
sns.boxplot(y=penguins.island, x=penguins.bill_length_mm, hue= penguins.sex)

# %%
sns.boxplot(y=penguins.island, x=penguins.bill_length_mm, hue= penguins.sex, order=['Biscoe','Torgersen','Dream'])

# %%
sns.boxplot(y=penguins.island, x=penguins.bill_length_mm, hue= penguins.sex, order=['Biscoe','Torgersen','Dream'], color='g')

# %%
sns.boxplot(y=penguins.island, x=penguins.bill_length_mm, hue= penguins.sex, order=['Biscoe','Torgersen','Dream'], whis=0.8)

# %%
sns.boxplot(y=penguins.island, x=penguins.bill_length_mm, hue= penguins.sex, order=['Biscoe','Torgersen','Dream'], whis=0.8,showcaps=False)

# %%
cars = sns.load_dataset('mpg')
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.distplot(cars.displacement)

# %%
sns.distplot(cars.displacement, kde=False)

# %%
sns.distplot(cars.displacement, kde=False, rug=True)

# %%
sns.distplot(cars.displacement, kde=False, rug=True, bins=20)

# %%
sns.distplot(cars.displacement, kde=False, rug=True, norm_hist=True, bins=10)

# %%
sns.distplot(cars.displacement, norm_hist=True, rug=True, rug_kws={'color':'red', 'height':'0.15'}, kde_kws={'lw':5}, bins=10, hist_kws={'color': 'green','alpha': 0.2, 'lw': 6, 'histtype': 'step'})

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
sns.boxplot(cars.mpg)

# %%
sns.boxplot(x=cars.origin, y=cars.mpg)

# %%
sns.boxplot(x=cars.origin, y=cars.mpg, hue=cars.cylinders)

# %%
sns.boxplot(x=cars.origin, y=cars.mpg, order=['japan','europe','usa'])

# %%
sns.boxplot(x=cars.origin, y=cars.mpg, order=['japan','europe','usa'], color='red')

# %%
sns.boxplot(x=cars.origin, y=cars.mpg, order=['japan','europe','usa'], width=0.3)

# %%
plt.figure(figsize=(16,6))

# %%
sns.lineplot(x=cars.mpg,y=cars.displacement)

# %%
fifa = pd.read_csv('fifa.csv', index_col='Date', parse_dates=True)
fifa.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %%
plt.figure()

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=fifa)

# %%
museum = pd.read_csv('museum_visitors.csv', index_col='Date', parse_dates=True)
museum.head()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-02-01                                  5029
# 2014-03-01                                  8129
# 2014-04-01                                  2824
# 2014-05-01                                 10694

# %%
museum['2018-07']['Chinese American Museum']['2018-07-01']
# Out:
# 2620

# %%
museum['2018-07']['Chinese American Museum'].sum()
# Out:
# 2620

# %%
museum.loc['2018-07-01','Chinese American Museum']
# Out:
# 2620

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=museum)

# %%
sns.lineplot(data=museum['Avila Adobe'])
plt.title('Montly visitors to Avila Adobe')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
ign = pd.read_csv('ign_scores.csv',index_col='Platform')
ign
# Out:
#                         Action  Action, Adventure  Adventure  Fighting  \
# Platform
# Dreamcast             6.882857           7.511111   6.281818  8.200000
# Game Boy Advance      6.373077           7.507692   6.057143  6.226316
# Game Boy Color        6.272727           8.166667   5.307692  4.500000
# GameCube              6.532584           7.608333   6.753846  7.422222
# Nintendo 3DS          6.670833           7.481818   7.414286  6.614286
# Nintendo 64           6.649057           8.250000   7.000000  5.681250
# Nintendo DS           5.903608           7.240000   6.259804  6.320000
# Nintendo DSi          6.827027           8.500000   6.090909  7.500000
# PC                    6.805791           7.334746   7.136798  7.166667
# PlayStation           6.016406           7.933333   6.313725  6.553731
# PlayStation 2         6.467361           7.250000   6.315152  7.306349
# PlayStation 3         6.853819           7.306154   6.820988  7.710938
# ...

# %%
ign.max()
# Out:
# Action               7.702857
# Action, Adventure    8.500000
# Adventure            8.057143
# Fighting             8.200000
# Platformer           8.568750
# Puzzle               8.250000
# RPG                  8.291667
# Racing               8.163636
# Shooter              8.042857
# Simulation           9.250000
# Sports               7.884397
# Strategy             8.900000
# dtype: float64

# %%
ign.Simulation.max()
# ign.max().max()
# Out:
# 9.25

# %%
ign[ign.Simulation==9.25]
# Out:
#                Action  Action, Adventure  Adventure  Fighting  Platformer  \
# Platform
# PlayStation 4    7.55           7.835294   7.388571      7.28    8.390909
#
#                Puzzle    RPG  Racing   Shooter  Simulation  Sports  Strategy
# Platform
# PlayStation 4     7.4  7.944    7.59  7.804444        9.25    7.43  6.566667

# %%
ign[ign.Simulation==9.25].index
# Out:
# Index(['PlayStation 4'], dtype='object', name='Platform')

# %%
ign.loc['PlayStation Vita'].min()
# Out:
# 5.725

# %%
ign.loc['PlayStation Vita'].index[-3]
# Out:
# 'Simulation'

# %%
sns.barplot(x=ign.index, y=ign.Racing)

# %%
plt.figure(figsize=(8,6))
sns.barplot(y=ign.index, x=ign.Racing)
plt.title('Average Score for Racing Games, by Platform')
# Out:
# Text(0.5, 1.0, 'Average Score for Racing Games, by Platform')

# %%
plt.figure(figsize=(9,9))
plt.title('Average Game Score, by Platform and Genre')
sns.heatmap(ign, annot=True)
plt.xlabel('Genre')
# Out:
# Text(0.5, 60.0, 'Genre')

# %%
insurance = pd.read_csv('insurance.csv')
insurance.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
sns.scatterplot(x=insurance.bmi, y=insurance.charges)

# %%
sns.regplot(x=insurance.bmi, y=insurance.charges)

# %%
sns.scatterplot(x=insurance.bmi, y=insurance.charges, hue=insurance.smoker)

# %%
sns.lmplot(x='bmi', y='charges', hue='smoker', data=insurance)

# %%
sns.swarmplot(x=insurance.charges, y=insurance.smoker)  #categorical scatter plot

# %% [markdown]
# ###### this plot shows us that:
#
# on average, non-smokers are charged less than smokers, and
# the customers who pay the most are smokers; whereas the customers who pay the least are non-smokers

# %%
sns.get_dataset_names()
# Out:
# C:\Users\chpra\anaconda3\lib\site-packages\seaborn\utils.py:384: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\Users\chpra\anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.distplot(iris.petal_length,kde=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-d8c733626048> in <module>
# ----> 1 sns.distplot(iris.petal_length,shade=True)
#
# TypeError: distplot() got an unexpected keyword argument 'shade'

# %%
sns.kdeplot(iris.petal_length, shade=True)

# %% [markdown]
# ### 2-D KDE Plots

# %%
sns.jointplot(x='petal_length', y='sepal_width', data=iris, kind='kde')

# %%
iris.species.value_counts()
# Out:
# versicolor    50
# setosa        50
# virginica     50
# Name: species, dtype: int64

# %%
iris_ver, iris_set, iris_vir = iris[iris.species=='versicolor'], iris[iris.species=='setosa'], iris[iris.species=='virginica']b

# %%
iris_ver.head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor

# %%
iris_set.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_vir.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica

# %%
sns.distplot(iris_set.petal_length, kde=False, label='setosa')
sns.distplot(iris_ver.petal_length, kde=False, label='versicolor')
sns.distplot(iris_vir.petal_length, kde=False, label='virginica')
plt.title('Histogram of petal lengths, by Species')
plt.legend()

# %%
sns.kdeplot(iris_set.petal_length, shade=True, label='setosa')
sns.kdeplot(iris_ver.petal_length, shade=True, label='versicolor')
sns.kdeplot(iris_vir.petal_length, shade=True, label='virginica')
plt.title('Distribution of petal lengths, by Species')
plt.legend()

# %%
from IPython.display import Image
Image(filename='sns_guide.png')

# %% [markdown]
# ### Trends - A trend is defined as a pattern of change.
# <u>`sns.lineplot`</u> -
#
#     Line charts are best to show trends over a period of time, and multiple lines can be used to show trends in more than one group.

# %% [markdown]
# ### Relationship - There are many different chart types that you can use to understand relationships between variables in your data.
# <u>`sns.barplot`</u> -
#
#     Bar charts are useful for comparing quantities corresponding to different groups.
# <u>`sns.heatmap`</u> -
#
#     Heatmaps can be used to find color-coded patterns in tables of numbers.
# <u>`sns.scatterplot`</u> -
#
#     Scatter plots show the relationship between two continuous variables; if color-coded, we can also show the relationship with a third categorical variable.
# <u>`sns.regplot`</u> -
#
#     Including a regression line in the scatter plot makes it easier to see any linear relationship between two variables.
# <u>`sns.lmplot`</u> -
#
#     This command is useful for drawing multiple regression lines, if the scatter plot contains multiple, color-coded groups.
# <u>`sns.swarmplot`</u> -
#
#     Categorical scatter plots show the relationship between a continuous variable and a categorical variable.

# %% [markdown]
# ### Distribution - We visualize distributions to show the possible values that we can expect to see in a variable, along with how likely they are.
# <u>`sns.distplot`</u> -
#
#     Histograms show the distribution of a single numerical variable.
# <u>`sns.kdeplot`</u> -
#
#     KDE plots (or 2D KDE plots) show an estimated, smooth distribution of a single numerical variable (or two numerical variables).
# <u>`sns.jointplot`</u> -
#
#     This command is useful for simultaneously displaying a 2D KDE plot with the corresponding KDE plots for each individual variable.

# %%
sns.get_dataset_names()
# Out:
# C:\Users\chpra\anaconda3\lib\site-packages\seaborn\utils.py:384: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\Users\chpra\anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
planets = sns.load_dataset('planets')
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
sns.lineplot(data=planets[['mass','distance','year']])

# %%
sns.set_style('darkgrid')
sns.lineplot(data=planets[['mass','distance','year']])
#Seaborn has five different themes: (1)"darkgrid", (2)"whitegrid", (3)"dark", (4)"white", and (5)"ticks"
